# %% [markdown]
# # Si446x

# %%
from si446x.si446xtrace import si446xtrace_test
cur_time, parse_time, format_time, trace = si446xtrace_test()
for e in trace.display(trace.filter()):
    print(e)
# Out:
# [1, '2017.04.29 01:54:07.480664', ' -0.019679', 'RADIO_PEND', '  f0:278 f2:266', ' fast_frr_rsp_s state: RX,modem_pend:  RSSI INVALID_PREAMBLE, rssi: 132']
# [2, '2017.04.29 01:54:07.481224', ' -0.019119', 'RADIO_CMD', '  f0:276 f1:273', ' change_state_cmd_s Next state: SPI_ACTIVE']
# [3, '2017.04.29 01:54:07.484239', ' -0.016104', 'RADIO_FRR', '  f0:278 f2:263', ' fast_frr_s state: RX, ph_pend:  FILTER_MATCH,modem_pend:  RSSI INVALID_PREAMBLE, rssi: 132']
# [4, '2017.04.29 01:54:07.487196', ' -0.013146', 'RADIO_PEND', '  f0:278 f2:266', ' fast_frr_rsp_s state: RX,modem_pend:  RSSI INVALID_PREAMBLE, rssi: 132']
# [5, '2017.04.29 01:54:07.487813', ' -0.012529', 'RADIO_CMD', '  f0:276 f1:273', ' change_state_cmd_s Next state: SPI_ACTIVE']
# [6, '2017.04.29 01:54:07.490819', ' -0.009523', 'RADIO_FRR', '  f0:278 f2:263', ' fast_frr_s state: RX, ph_pend:  FILTER_MATCH,modem_pend:  RSSI INVALID_PREAMBLE, rssi: 132']
# ...

# %%
from si446x.si446xact import si446xact_test
actions = si446xact_test()
print(actions)

# %%
from si446x.si446xradio import si446xradio_test
trace, radio = si446xradio_test()
# Out:
# <built-in function get_config_wds>
# len(6)    command(11)    Group(00)
# len(5)    command(11)    Group(00)
# len(6)    command(11)    Group(01)
# len(8)    command(11)    Group(02)
# len(5)    command(11)    Group(10)
# len(5)    command(11)    Group(10)
# len(7)    command(11)    Group(11)
# len(5)    command(11)    Group(12)
# len(5)    command(11)    Group(12)
# len(16)    command(11)    Group(20)
# len(5)    command(11)    Group(20)
# len(12)    command(11)    Group(20)
# len(13)    command(11)    Group(20)
# len(11)    command(11)    Group(20)
# len(5)    command(11)    Group(20)
# len(13)    command(11)    Group(20)
# len(12)    command(11)    Group(20)
# len(5)    command(11)    Group(20)
# len(5)    command(11)    Group(20)
# len(16)    command(11)    Group(21)
# len(16)    command(11)    Group(21)
# len(16)    command(11)    Group(21)
# len(8)    command(11)    Group(22)
# len(11)    command(11)    Group(23)
# len(12)    command(11)    Group(40)
# ...

# %%
from si446x.si446xdvr import si446xdvr_test
fsm, radio, dbus = si446xdvr_test()
# Out:
# trace disabled
# 0.0613729953766:1000 fsm['actions'].output_A_NOP(si446x.si446xFSM.Events.E_0NOP)
# 0.0582849979401:1000 a.output_A_NOP(si446x.si446xFSM.Events.E_0NOP)
# 0.00397086143494:1000 si446x.si446xact.no_op(fsm['actions'],si446x.si446xFSM.Events.E_0NOP)
# trace enabled
# 0.206269979477:1000 fsm['actions'].output_A_NOP(si446x.si446xFSM.Events.E_0NOP)
# 0.204161882401:1000 a.output_A_NOP(si446x.si446xFSM.Events.E_0NOP)
# 0.00425505638123:1000 si446x.si446xact.no_op(fsm['actions'],si446x.si446xFSM.Events.E_0NOP)

# %%
help(Si446xDbus)
# Out:
# Help on class Si446xDbus in module si446x.si446xdvr:
#
# class Si446xDbus(txdbus.objects.DBusObject)
#  |  Dbus Interface Class for si446x Radio Driver
#  |
#  |  Method resolution order:
#  |      Si446xDbus
#  |      txdbus.objects.DBusObject
#  |      __builtin__.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, objectPath, trace=None)
#  |
#  |  async_interrupt(self, channel)
#  |      Handle external device interrupt
#  |
#  |      First, need to synchronize the hardware interrupt event with
#  |      the Twisted thread handler using callFromThread(radio_interrupt).
#  |      Twisted provides a way to defer processing of external events
#  |      until it has reached an appropriate opportunity in its processing
#  |      loop. We use this to synchronize the external interrupt, thus
#  |      ensuring control to critical access resources like the driver
#  |      state machine and radio device registers.
#  |
# ...
