# %% [markdown]
# # Si446x Device Direct Access TagNet Software Image Load

# %%
from __future__ import print_function
from builtins import *                  # python3 types
from time import sleep
from datetime import datetime
import struct as pystruct
from binascii import hexlify
import os.path

# %%
# !pwd
# %autosave 0
import sys
sys.path.append("../si446x/si446x")
# %run '../si446x/si446x/notebooks/si446x_Device_Layer.ipynb'
# Out:
# /mnt/Open/TagNet/notebooks
# Autosave disabled
# Autosave disabled
# Autosave disabled
# /mnt/Open/TagNet/si446x/si446x/notebooks
#
# /usr/lib/python2.7
# /usr/lib/python2.7/plat-arm-linux-gnueabihf
# /usr/lib/python2.7/lib-tk
# /usr/lib/python2.7/lib-old
# /usr/lib/python2.7/lib-dynload
# /usr/local/lib/python2.7/dist-packages
# /usr/local/lib/python2.7/dist-packages/pydbus-0.6.0-py2.7.egg
# /usr/local/lib/python2.7/dist-packages/tagnet-0.0.4-py2.7.egg
# /usr/local/lib/python2.7/dist-packages/enum34-1.1.6-py2.7.egg
# /usr/local/lib/python2.7/dist-packages/DateTime-4.1.1-py2.7.egg
# /usr/local/lib/python2.7/dist-packages/uuid-1.30-py2.7.egg
# /usr/local/lib/python2.7/dist-packages/pytz-2016.10-py2.7.egg
# /usr/local/lib/python2.7/dist-packages/RPIO-0.10.0-py2.7-linux-armv7l.egg
# /usr/local/lib/python2.7/dist-packages/si446x-0.1.53-py2.7-linux-armv7l.egg
# /usr/local/lib/python2.7/dist-packages
# /usr/lib/python2.7/dist-packages
# /usr/lib/python2.7/dist-packages/PILcompat
# /usr/lib/python2.7/dist-packages/gtk-2.0
# /usr/lib/pymodules/python2.7
# /usr/local/lib/python2.7/dist-packages/IPython/extensions
# /home/pi/.ipython
# ../si446x/si446x
# ../si446x
# ../
# Help on class Si446xRadio in module si446xradio:
#
# class Si446xRadio(future.types.newobject.newobject)
#  |  Class for handling low level Radio device operations.
#  |
#  |  This is the radio API for the SI446x ('63 specifically, but verified
#  |  to operate with '68 as well -tbd)
#  |
#  |  Method resolution order:
#  |      Si446xRadio
#  |      future.types.newobject.newobject
#  |      __builtin__.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, device=0, callback=None, trace=None)
#  |      Initialize Si446x Radio Device API
#  |
#  |      RPi defines a single SPI interface with two chip selects. This
#  |      allows for two devices (0 and 1) to be connected and separately
#  |      accessed. A SpiInterface object is created for one of these devices.
#  |
#  |      The callback function handles the RPi interrupt from the GPIO
#  |      pin which should be wired to the radio interrupt pin. See
#  |
#  |  change_state(self, state, wait=0)
#  |      change_state - force radio chip to change to specific state
#  |
#  |      waits (ms) for acknowledgement that radio has processed the change.
#  |
#  |  check_CCA(self)
#  |      Perform Clear Channel Assessment
#  |
#  |      Return False if signal is detected (rssi above threshold).
#  |
#  |  clear_interrupts(self, clr_flags=None)
#  |      Clear radio chip pending interrupts
#  |
#  |      Default (nothing in clr_flags) then clear all interrupts by
#  |      sending short command. Otherwise, send the flags to clear.
#  |      (flag == 0 means clear pending interrupt (yes, 0))
#  |
#  |  config_frr(self, a_mode='CURRENT_STATE', b_mode='INT_PH_PEND', c_mode='INT_MODEM_PEND', d_mode='LATCHED_RSSI')
#  |      Configure the Fast Response Registers (FRR) to the specific Driver usage
#  |
#  |      FRR should be set explicitly right after POWER_UP to the following:
#  |      A: CURRENT_STATE   - current state of the radio
#  |      B: PH_PEND         - packet handler pending interrupts
#  |      C: MODEM_PEND      - modem pending interrupts
#  |      D: LATCHED_RSSI    - current latched RSSI valu
#  |
#  |      We use LR (Latched_RSSI) when receiving a packet.  The RSSI value is
#  |      attached to the last RX packet.  The Latched_RSSI value may, depending
#  |      on configuration, be associated with some number of bit times once RX
#  |      is enabled or when SYNC is detected.
#  |
#  |  disable_interrupt(self)
#  |      Disable radio chip hardware interrupt
#  |
#  |  dump_radio(self)
#  |      Dump all of the current radio decice property settings
#  |
#  |      Since all SPI I/O operations are traced, this has the side effect that the
#  |      dump is written out to the radio trace.
#  |      A shadow of all of the property information is maintained by 'dump_strings'
#  |      in memory and is returned by this call.
#  |
#  |  enable_interrupts(self)
#  |      Enable radio chip interrupts
#  |
#  |      Callback function is defined when object was created. It is bound
#  |      the interrupt and will be called when the GPIO transitions from
#  |      high to low.
#  |
#  |  fast_all(self)
#  |      Get all four fast response registers
#  |
#  |  fast_device_state(self)
#  |      Get current radio device state from fast read register
#  |
#  |  fast_latched_rssi(self)
#  |      Get RSSI from fast read register
#  |
#  |      The radio chip measures the receive signal strength (RSSI) during the
#  |      beginning of receiving a packet, and latches this value.
#  |
#  |  fast_modem_pend(self)
#  |      Get modem pending interrupt flags from fast read register
#  |
#  |  fast_ph_pend(self)
#  |      Get packet handler (ph) pending interrupt flags from fast read register
#  |
#  |  fifo_info(self, rx_flush=False, tx_flush=False)
#  |      Get the current tx/rx fifo depths and optionally flush
#  |
#  |      Returns a list of [rx_fifo_count, tx_fifo_space]
#  |
#  |  get_channel(self)
#  |      Get current radio channel
#  |
#  |  get_chip_status(self)
#  |      Get current chip status
#  |
#  |      No change to current pending interrupts.
#  |
#  |  get_clear_interrupts(self, clr_flags=None)
#  |      Clear radio chip pending interrupts
#  |
#  |      The interrupts to clear can be specified (clr_pending_int_s).
#  |      If no clr_flags passed, then will clear all pending interrupts.
#  |
#  |      Returns pending interrupt conditions existing prior to
#  |      clear (int_status_rsp_s).
#  |
#  |      Refer to structures defined by the Si4463 radio API revB1B.
#  |
#  |  get_config_lists(self)
#  |      Get list of radio configuration string generator functions
#  |
#  |      Each item in the returned list is a pointer to a function
#  |      that can be called successively to traverse the config
#  |      strings in its list. The first call is passed zero to
#  |      start with the first string in the list. Successive calls
#  |      are passed the offset into the list for the next appropriate
#  |      string (the sum of all previous string lengths). The
#  |      list is terminated by a zero-length string.
#  |
#  |      There are at least two configuration strings, one produced
#  |      by the Silicon Labs WDS program. The other is defined
#  |      in the platform configuration file that specifies details
#  |      about this specific hardware instantiation (e.g., GPIO pin
#  |      assignments). Each list consists of a set of Pascal-style
#  |      strings that consist of a one byte length field followed
#  |      by specified number of bytes (and NOT null-terminated like
#  |      c-style strings). The list consists of zero or more strings
#  |      concatenated together, terminating in a zero-length string.
#  |      See radioconfig/si446xcfg.c for more details.
#  |
#  |  get_cts(self)
#  |      Get current readiness radio chip command processor
#  |
#  |      Read CTS, return true if high
#  |
#  |  get_gpio(self)
#  |      Get current state and configuration of radio chip GPIO pins
#  |
#  |  get_interrupts(self)
#  |      get current interrupt conditions
#  |
#  |      doesn't clear any interrupts (set all flags to 1)
#  |
#  |  get_packet_info(self)
#  |      Get the length of the packet as received by the radio
#  |
#  |  get_property(self, group, prop, len)
#  |      Read one or more contiguous radio chip properties
#  |
#  |      Returns byte array since this is potentially only portion of a property group
#  |
#  |  power_up(self)
#  |      Start up the Radio.
#  |
#  |  read_cmd_buff(self)
#  |      Read Clear-to-send (CTS) status via polling command over SPI
#  |
#  |      Pull nsel low. read cts from cmd_buff. If cts=0xff, then
#  |      pull nsel high and repeat. Else return copy of the command buf
#  |
#  |  read_rx_fifo(self, len)
#  |      Read data from the radio chip receive fifo
#  |      returns bytesarray
#  |
#  |  read_silicon_info(self)
#  |      Read silicon manufacturing information
#  |
#  |  send_config(self, props)
#  |      Send a config string to the radio chip
#  |
#  |      Already formatted into proper byte string with command and parameters
#  |
#  |  set_channel(self, num)
#  |      Set radio channel
#  |
#  |  set_power(self, level)
#  |      Set radio transmission power level (0x7f = 20dBm)
#  |
#  |  set_property(self, pg, ps, pd)
#  |      Set one or more contiguous radio device properties
#  |
#  |      Up to 12 properties at a time (msg buffer is 16, subtrace for
#  |      cts and set_property_header). Higher level code would need to
#  |      split up the data into more than one set_property call to set
#  |      any group larger than 12 (like modem for instance).
#  |
#  |  shutdown(self)
#  |      Power off the radio chip
#  |
#  |  start_rx(self, len, channel=255)
#  |      Transition the radio chip to the receive enabled state
#  |
#  |  start_rx_short(self)
#  |      Transition the radio chip to the receive enabled state
#  |
#  |  start_tx(self, len, channel=255)
#  |      Transition the radio chip to the transmit state.
#  |
#  |  trace_radio(self)
#  |      Dump the saved radio chip configuration to the trace buffer
#  |
#  |  unshutdown(self)
#  |      Power on the radio chip.
#  |
#  |      Set GPIO pin 18 (GPIO23) connected to si446x.sdn
#  |
#  |  write_tx_fifo(self, dat)
#  |      Write data into the radio chip transmit fifo
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from future.types.newobject.newobject:
#  |
#  |  __long__(self)
#  |
#  |  __native__(self)
#  |      Hook for the future.utils.native() function
#  |
#  |  __nonzero__(self)
#  |
#  |  __unicode__(self)
#  |
#  |  next(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from future.types.newobject.newobject:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
# si446x driver version: 0.1.56
#
# compiled config strings (wdds + local):
#
# 1300 0000 0000 0000
# 1100 0200 5200
# 1100 0103 60
# 1101 0200 0120
# 1110 0100 0a
# 1110 0104 31
# 1111 0300 01b4 2b
# 1112 0106 02
# 1112 010f 04
# 1120 0c00 0300 0706 1a80 05c9 c380 0005
# 1120 010c 76
# 1120 0818 0180 0803 8000 2020
# 1120 0922 0177 015d 8600 af02 c2
# 1120 072c 0436 801d 1004 80
# 1120 0135 e2
# 1120 0938 1152 5200 1aff ff00 2a
# 1120 0842 a402 d683 00ad 0180
# 1120 014e 40
# 1120 0151 0a
# 1121 0c00 a281 26af 3fee c8c7 dbf2 0208
# 1121 0c0c 0703 15fc 0f00 a281 26af 3fee
# 1121 0c18 c8c7 dbf2 0208 0703 15fc 0f00
# 1122 0400 087f 003d
# 1123 0700 2c0e 0b04 0c73 03
# 1140 0800 380e eeee 4444 20fe
# 131c 0821 2000 0000
# 1100 0103 60
# 1101 0400 033b 2b00
# 1110 0900 0814 000f 31
# 1112 0700 8501 08ff ff00 82
# 1112 0508 2a01 0030 30
# 1112 060d 0001 04a2 0000
# 1112 0a21 0001 0482 00ff 000a 0000
# 1120 034a 200c 25
# ('ff02 4468 0086 0200 06 ', Container({'customer': 0, 'pbuild': 0, 'cts': 255, 'romid': 6, 'part': 17512, 'chiprev': 2, 'id': 34306}))
# ('ff02 4468 0086 02 ', Container({'revbranch': 68, 'cts': 255, 'patch': 134, 'revext': 2, 'revint': 104, 'func': 2}))
# Container:
#     cts = 255
#     gpio_cfg_s = [
#         Container:
#             state = 'ACTIVE'
#             pull_ctl = 'PULL_DIS'
#             mode = 'IN_SLEEP'
#         Container:
#             state = 'INACTIVE'
#             pull_ctl = 'PULL_DIS'
#             mode = 'CTS'
#         Container:
#             state = 'INACTIVE'
#             pull_ctl = 'PULL_DIS'
#             mode = 'RX_STATE'
#         Container:
#             state = 'INACTIVE'
#             pull_ctl = 'PULL_DIS'
#             mode = 'TX_STATE'
#     ]
#     nirq_cfg_s = Container:
#         state = 'ACTIVE'
#         pull_ctl = 'PULL_DIS'
#         mode = 'NIRQ'
#     sdo_cfg_s = Container:
#         state = 'INACTIVE'
#         pull_ctl = 'PULL_DIS'
#         mode = 'SDO'
#     gen_config = Container:
#         drive_strength = 'HIGH'
# [(bytearray(b'\xff\x02Dh\x00\x86\x02\x00\x06'), Container({'customer': 0, 'pbuild': 0, 'cts': 255, 'romid': 6, 'part': 17512, 'chiprev': 2, 'id': 34306})), (bytearray(b'\xff\x02Dh\x00\x86\x02'), Container({'revbranch': 68, 'cts': 255, 'patch': 134, 'revext': 2, 'revint': 104, 'func': 2}))]
#
# int_ctl_group_s: 4
# 033b 2b00
#  enable:  MODEM_INT_STATUS_EN PH_INT_STATUS_EN ph_pend:  PACKET_SENT PACKET_RX CRC_ERROR TX_FIFO_ALMOST_EMPTY RX_FIFO_ALMOST_FULL modem_pend:  INVALID_SYNC RSSI PREAMBLE_DETECT SYNC_DETECT
#
# global_group_s: 10
# 5200 1860 0000 0160 0000
# Container:
#     xo_tune = 82
#     clk_cfg = Container:
#         divided_clk_en = 'DISABLE'
#         divided_clk_sel = 'DIV_1'
#         clk_32k_sel = 'OFF'
#     low_batt_thresh = 24
#     global_config = Container:
#         sequencer_mode = 'FAST'
#         fifo_mode = 'SPLIT_FIFO'
#         protocol = 'GENERIC'
#         power_mode = 'HIGH_PERF'
#     wut_config = Container:
#         wut_ldc_enable = 'DISABLE'
#         wut_cal_period = '_1_SEC'
#         wut_lbd_en = 'DISABLE'
#         wut_en = 'DISABLE'
#         cal_en = 'DISABLE'
#     wut_m = 1
#     wut_r = Container:
#         RESERVED_WRITE_ONE = 'ONE'
#         wut_sleep = 'SLEEP'
#         wut_r_ = 0
#     wut_ldc = 0
#     wut_cal = 0
#
# synth_group_s: 8
# 2c0e 0b04 0c73 0305
# Container:
#     pfdcp_cpff = 44
#     pfdcp_cpint = 14
#     vco_kv = 11
#     lpfilt3 = 4
#     lpfilt2 = 12
#     lpfilt1 = 115
#     lpfilt0 = 3
#     vco_kvcal = 5
#
# frr_ctl_group_s: 4
# 0904 060a
# CURRENT_STATE  INT_PH_PEND  INT_MODEM_PEND  LATCHED_RSSI
#
# modem_group_s: 82
# 0300 0706 1a80 05c9 c380 0005 7600 0067 604d 3621 1108 0301 0180 0803 8000 2020 0000 0177 015d 8600 af02 c200 0436 801d 1004 8000 00e2 0000 1152 5200 1aff ff00 2a0c a402 d683 00ad 0180 200c 2500 4003 000a
# Container:
#     mod_type = Container:
#         tx_direct_mode_type = 'SYNC'
#         tx_driect_mode_gpio = 'GPIO_1'
#         mod_source = 'PACKET'
#         mod_type = '_2GFSK'
#     map_control = Container:
#         enmanch = 'DISABLE'
#         eninv_rxbit = 'NO_INVERT'
#         eninv_txbit = 'NO_INVERT'
#         eninv_fd = 'NO_INVERT_POL'
#     dsm_ctrl = Container:
#         dsmclk_sel = 'PLL'
#         dsm_mode = 'MASH'
#         dsmdt_en = 'DISABLE'
#         rsmdttp = 'ZERO'
#         dsm_rst = 'ENABLE'
#         dsm_lsb = 'FORCED_HIGH'
#         dsm_order = 'THIRD_ORDER'
#     data_rate = Container:
#         m = 400000
#     tx_nco_mode = Container:
#         txosr = 'GAUSS_40X'
#         ncomod = 30000000
#     freq_dev = Container:
#         freqdev = 1398
#     freq_offset = 0
#     filter_coeff = 'g`M6!\x11\x08\x03\x01'
#     tx_ramp_delay = 1
#     mdm_ctrl = 128
#     if_control = Container:
#         zeroif = 'NORMAL'
#         fixif = 'FIXED'
#     if_freq = Container:
#         hertz = 229376
#     decimation_cfg1 = 32
#     decimation_cfg0 = 32
#     bcr_osr = 375
#     bcr_nco = Container:
#         offset = 89478
#     bcr_gain = 175
#     bcr_gear = 2
#     bcr_misc1 = 194
#     bcr_misc0 = 0
#     afc_gear = 4
#     afc_wait = 54
#     afc_gain = 32797
#     afc_limiter = 4100
#     afc_misc = 128
#     afc_zipoff = 0
#     adc_ctrl = 0
#     agc_control = 226
#     agc_window_size = 17
#     agc_rffpd_decay = 82
#     agc_ifpd_decay = 82
#     fsk4_gain1 = 0
#     fsk4_gain0 = 26
#     fsk4_th = 65535
#     fsk4_map = 0
#     ook_pdtc = 42
#     ook_blopk = 12
#     ook_cnt1 = 164
#     ook_misc = 2
#     raw_search = 214
#     raw_control = 131
#     raw_eye = 173
#     ant_div_mode = 1
#     ant_div_control = 128
#     rssi_thresh = 32
#     rssi_jump_thesh = 12
#     rssi_control = Container:
#         check_thresh_at_latch = 'ENABLE'
#         average = 'AVERAGE4'
#         latch = 'RX_STATE3'
#     rssi_control2 = Container:
#         rssijmp_dwn = 'DISABLE'
#         rssijmp_up = 'DISABLE'
#         enrssijmp = 'DISABLE'
#         jmpdlylen = '_2_Tb'
#         enjmprx = 'NO_RESET'
#     rssi_comp = 64
#     clkgen_band = 10
#
# rx_hop_group_s: 66
# 0401 0001 0203 0405 0607 0809 0a0b 0c0d 0e0f 1011 1213 1415 1617 1819 1a1b 1c1d 1e1f 2021 2223 2425 2627 2829 2a2b 2c2d 2e2f 3031 3233 3435 3637 3839 3a3b 3c3d 3e3f
# Container:
#     control = 4
#     table_size = 1
#     table_entries = '\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\x0c\r\x0e\x0f\x10\x11\x12\x13\x14\x15\x16\x17\x18\x19\x1a\x1b\x1c\x1d\x1e\x1f !"#$%&\'()*+,-./0123456789:;<=>?'
#
# freq_control_group_s: 8
# 380e eeee 4444 20fe
# Container:
#     inte = 56
#     frac = Container:
#         i = 978670
#     channel_step_size = 17476
#     w_size = 32
#     vcocnt_rx_adj = 254
#
# match_group_s: 12
# 0000 0000 0000 0000 0000 0000
# Container:
#     match_field_s = [
#         Container:
#             value = 0
#             mask = 0
#             ctrl = 0
#         Container:
#             value = 0
#             mask = 0
#             ctrl = 0
#         Container:
#             value = 0
#             mask = 0
#             ctrl = 0
#         Container:
#             value = 0
#             mask = 0
#             ctrl = 0
#     ]
#
# sync_group_s: 5
# 01b4 2b2d d4
# Container:
#     config = Container:
#         skip_tx = 'SYNC_XMIT'
#         rx_errors = 0
#         4fsk = 'DISABLE'
#         manch = 'DISABLE'
#         length = 'LEN_2_BYTES'
#     sync_bits = 3022728660L
#
# preamble_group_s: 14
# 0814 000f 3100 0000 0000 0000 0000
# Container:
#     tx_length = 8
#     config_std_1 = Container:
#         skip_sync_to = 'DISABLE'
#         wut_r_ = 20
#     config_nstd = Container:
#         rx_errors = 0
#         pattern_length = 0
#     config_std_2 = Container:
#         rx_preamble_timeout_extend = 0
#         rx_preamble_timeout = 15
#     config = Container:
#         pream_frist_1_or_0 = 'First_1'
#         length_config = 'BYTE'
#         man_const = 'NO_CON'
#         man_en = 'NO_MAN'
#         standard_pream = 'PRE_1010'
#     pattern = 0
#     postamble_config = Container:
#         postamble_enable = 'DISABLE'
#         pkt_valid_on_postamble = 'TRUE'
#         postamble_size = '_8_BITS'
#     postamble_pattern = 0
#
# pkt_group_s: 53
# 8501 08ff ff00 8200 2a01 0010 1000 0104 a200 0000 0000 0000 0000 0000 0000 0000 0000 0104 8200 ff00 0a00 0000 0000 0000 0000 0000 00
# Container:
#     crc_config = Container:
#         crc_seed = 'CRC_SEED_1'
#         crc_polynomial = 'CCITT_16'
#     wht_poly = 264
#     wht_seed = 65535
#     wht_bit_num = Container:
#         sw_wht_ctrl = 'DISABLE'
#         sw_crc_ctrl = 'DISABLE'
#         wht_bit_num_ = 'ENUM_0'
#     config1 = Container:
#         ph_field_split = 'FIELD_SPLIT'
#         ph_rx_disable = 'RX_ENABLED'
#         4fsk_en = 'DISABLE'
#         manch_pol = 'PATTERN_10'
#         crc_invert = 'NO_INVERT'
#         crc_endian = 'MSBYTE_FIRST'
#         bit_order = 'LSBIT_FIRST'
#     len = Container:
#         endian = 'BIG'
#         size = 'ONE_BYTE'
#         in_fifo = 'LEAVE_IN'
#         dst_field = 'FIELD_2'
#     len_field_source = Container:
#         src_field = 'FIELD_1_'
#     len_adjust = 0
#     tx_threshold = 16
#     rx_threshold = 16
#     tx1 = Container:
#         length = 1
#         config = Container:
#             4fsk = 'DISABLE'
#             pn_start = 'LOAD'
#             whiten = 'DISABLE'
#             manch = 'DISABLE'
#         crc_config = Container:
#             crc_start = 'ENABLE'
#             send_crc = 'ENABLE'
#             check_crc = 'DISABLE'
#             crc_enable = 'ENABLE'
#     tx2 = Container:
#         length = 0
#         config = Container:
#             4fsk = 'DISABLE'
#             pn_start = 'CONTINUE'
#             whiten = 'DISABLE'
#             manch = 'DISABLE'
#         crc_config = Container:
#             crc_start = 'DISABLE'
#             send_crc = 'DISABLE'
#             check_crc = 'DISABLE'
#             crc_enable = 'DISABLE'
#     tx3 = Container:
#         length = 0
#         config = Container:
#             4fsk = 'DISABLE'
#             pn_start = 'CONTINUE'
#             whiten = 'DISABLE'
#             manch = 'DISABLE'
#         crc_config = Container:
#             crc_start = 'DISABLE'
#             send_crc = 'DISABLE'
#             check_crc = 'DISABLE'
#             crc_enable = 'DISABLE'
#     tx4 = Container:
#         length = 0
#         config = Container:
#             4fsk = 'DISABLE'
#             pn_start = 'CONTINUE'
#             whiten = 'DISABLE'
#             manch = 'DISABLE'
#         crc_config = Container:
#             crc_start = 'DISABLE'
#             send_crc = 'DISABLE'
#             check_crc = 'DISABLE'
#             crc_enable = 'DISABLE'
#     tx5 = Container:
#         length = 0
#         config = Container:
#             4fsk = 'DISABLE'
#             pn_start = 'CONTINUE'
#             whiten = 'DISABLE'
#             manch = 'DISABLE'
#         crc_config = Container:
#             crc_start = 'DISABLE'
#             send_crc = 'DISABLE'
#             check_crc = 'DISABLE'
#             crc_enable = 'DISABLE'
#     rx1 = Container:
#         length = 1
#         config = Container:
#             4fsk = 'DISABLE'
#             pn_start = 'LOAD'
#             whiten = 'DISABLE'
#             manch = 'DISABLE'
#         crc_config = Container:
#             crc_start = 'ENABLE'
#             send_crc = 'DISABLE'
#             check_crc = 'DISABLE'
#             crc_enable = 'ENABLE'
#     rx2 = Container:
#         length = 255
#         config = Container:
#             4fsk = 'DISABLE'
#             pn_start = 'CONTINUE'
#             whiten = 'DISABLE'
#             manch = 'DISABLE'
#         crc_config = Container:
#             crc_start = 'DISABLE'
#             send_crc = 'DISABLE'
#             check_crc = 'ENABLE'
#             crc_enable = 'ENABLE'
#     rx3 = Container:
#         length = 0
#         config = Container:
#             4fsk = 'DISABLE'
#             pn_start = 'CONTINUE'
#             whiten = 'DISABLE'
#             manch = 'DISABLE'
#         crc_config = Container:
#             crc_start = 'DISABLE'
#             send_crc = 'DISABLE'
#             check_crc = 'DISABLE'
#             crc_enable = 'DISABLE'
#     rx4 = Container:
#         length = 0
#         config = Container:
#             4fsk = 'DISABLE'
#             pn_start = 'CONTINUE'
#             whiten = 'DISABLE'
#             manch = 'DISABLE'
#         crc_config = Container:
#             crc_start = 'DISABLE'
#             send_crc = 'DISABLE'
#             check_crc = 'DISABLE'
#             crc_enable = 'DISABLE'
#     rx5 = Container:
#         length = 0
#         config = Container:
#             4fsk = 'DISABLE'
#             pn_start = 'CONTINUE'
#             whiten = 'DISABLE'
#             manch = 'DISABLE'
#         crc_config = Container:
#             crc_start = 'DISABLE'
#             send_crc = 'DISABLE'
#             check_crc = 'DISABLE'
#             crc_enable = 'DISABLE'
#
# modem_chflt_group_s: 36
# a281 26af 3fee c8c7 dbf2 0208 0703 15fc 0f00 a281 26af 3fee c8c7 dbf2 0208 0703 15fc 0f00
# Container:
#     chflt_rx1_chflt_coe = '\xa2\x81&\xaf?\xee\xc8\xc7\xdb\xf2\x02\x08\x07\x03\x15\xfc\x0f\x00'
#     chflt_rx2_chflt_coe = '\xa2\x81&\xaf?\xee\xc8\xc7\xdb\xf2\x02\x08\x07\x03\x15\xfc\x0f\x00'
#
# pa_group_s: 6
# 087f 003d 8023
# power level: 127
#
# === total: 308
# FRR_CTL Struct('frr_ctl_group_s')[02]: (4) 0904 060a
# CURRENT_STATE  INT_PH_PEND  INT_MODEM_PEND  LATCHED_RSSI
# Container:
#     a_mode = 'CURRENT_STATE'
#     b_mode = 'INT_PH_PEND'
#     c_mode = 'INT_MODEM_PEND'
#     d_mode = 'LATCHED_RSSI'
# ()
# PA Struct('pa_group_s')[22]: (6) 087f 003d 0023
# power level: 127
# Container:
#     mode = Container:
#         ext_pa_ramp = 'DISABLE'
#         pa_sel = 2
#         pa_mode = 'CLASS_E'
#     pwr_lvl = Container:
#         ddac = 127
#     bias_clkduty = Container:
#         clk_duty = 'DIFF_50'
#         ob = 0
#     fsk_mod_dly = Container:
#         fsk_mod_dly = '_6_US'
#         tc = 29
#     ramp_ex = Container:
#         tc = 0
#     ramp_down_delay = 35
# ()
# pa_group_s: power level: 0
# Struct('pa_group_s'): 087f 003d 0023
# Container:
#     mode = Container:
#         ext_pa_ramp = 'DISABLE'
#         pa_sel = 2
#         pa_mode = 'CLASS_E'
#     pwr_lvl = Container:
#         ddac = 127
#     bias_clkduty = Container:
#         clk_duty = 'DIFF_50'
#         ob = 0
#     fsk_mod_dly = Container:
#         fsk_mod_dly = '_6_US'
#         tc = 29
#     ramp_ex = Container:
#         tc = 0
#     ramp_down_delay = 35
# power level: 127
#
#  programmed config strings:
# 1300 0000 0000 0000
# 1100 0200 5200
# 1100 0103 60
# 1101 0200 0120
# 1110 0100 0a
# 1110 0104 31
# 1111 0300 01b4 2b
# 1112 0106 02
# 1112 010f 04
# 1120 0c00 0300 0706 1a80 05c9 c380 0005
# 1120 010c 76
# 1120 0818 0180 0803 8000 2020
# 1120 0922 0177 015d 8600 af02 c2
# 1120 072c 0436 801d 1004 80
# 1120 0135 e2
# 1120 0938 1152 5200 1aff ff00 2a
# 1120 0842 a402 d683 00ad 0180
# 1120 014e 40
# 1120 0151 0a
# 1121 0c00 a281 26af 3fee c8c7 dbf2 0208
# 1121 0c0c 0703 15fc 0f00 a281 26af 3fee
# 1121 0c18 c8c7 dbf2 0208 0703 15fc 0f00
# 1122 0400 087f 003d
# 1123 0700 2c0e 0b04 0c73 03
# 1140 0800 380e eeee 4444 20fe
# 131c 0821 2000 0000
# 1100 0103 60
# 1101 0400 033b 2b00
# 1110 0900 0814 000f 31
# 1112 0700 8501 08ff ff00 82
# 1112 0508 2a01 0030 30
# 1112 060d 0001 04a2 0000
# 1112 0a21 0001 0482 00ff 000a 0000
# 1120 034a 200c 25
#
#  const config strings:
# 0201 0001 c9c3 80
# 1300 0000 0000 0000
# 1100 0200 5200
# 1100 0103 60
# 1101 0200 0120
# 1102 0400 0000 0000
# 1110 0100 0a
# 1110 0104 31
# 1111 0300 01b4 2b
# 1112 0106 02
# 1112 010f 04
# 1120 0c00 0300 0706 1a80 05c9 c380 0005
# 1120 010c 76
# 1120 0818 0180 0803 8000 2020
# 1120 0922 0177 015d 8600 af02 c2
# 1120 072c 0436 801d 1004 80
# 1120 0135 e2
# 1120 0938 1152 5200 1aff ff00 2a
# 1120 0842 a402 d683 00ad 0180
# 1120 014e 40
# 1120 0151 0a
# 1121 0c00 a281 26af 3fee c8c7 dbf2 0208
# 1121 0c0c 0703 15fc 0f00 a281 26af 3fee
# 1121 0c18 c8c7 dbf2 0208 0703 15fc 0f00
# 1122 0400 087f 003d
# 1123 0700 2c0e 0b04 0c73 03
# 1140 0800 380e eeee 4444 20fe
# 131c 0821 2000 0000
# 1100 0103 60
# 1101 0400 033b 2b00
# 1110 0900 0814 000f 31
# 1112 0700 8501 08ff ff00 82
# 1112 0508 2a01 0030 30
# 1112 060d 0001 04a2 0000
# 1112 0a21 0001 0482 00ff 000a 0000
# 1120 034a 200c 25
# Struct('frr_ctl_group_s'): 0904 060a
# Container:
#     a_mode = 'CURRENT_STATE'
#     b_mode = 'INT_PH_PEND'
#     c_mode = 'INT_MODEM_PEND'
#     d_mode = 'LATCHED_RSSI'
#  PA power level: 10
#  PA power level: 32
# Container:
#     mode = Container:
#         ext_pa_ramp = 'DISABLE'
#         pa_sel = 2
#         pa_mode = 'CLASS_E'
#     pwr_lvl = Container:
#         ddac = 32
#     bias_clkduty = Container:
#         clk_duty = 'DIFF_50'
#         ob = 0
#     fsk_mod_dly = Container:
#         fsk_mod_dly = '_6_US'
#         tc = 29
#     ramp_ex = Container:
#         tc = 0
#     ramp_down_delay = 35
# thresh: 20
# 80 c64,64wc38,16wwwf64:80
# 640102030405060708090a0b0c0d0e0f101112131415161718191a1b1c1d1e1f202122232425262728292a2b2c2d2e2f303132333435363738393a3b3c3d3e3f404142434445464748494a4b4c4d4e4f
#
# done

# %%
import sys
sys.path.append("../tagnet/tagnet")
from tagmessages import TagMessage, TagPoll, TagGet, TagPut, TagDelete, TagHead
from tagnames import TagName
from tagtlv import TagTlv, TagTlvList, tlv_types

# %%
import datetime
print('Test Start Time: {}'.format(datetime.datetime.now()))
print('Si446x Radio Device Driver Version: {}'.format(si446x_device_version()))
# Out:
# Test Start Time: 2017-11-28 12:31:20.376345
# Si446x Radio Device Driver Version: 0.1.56

# %% [markdown]
# ##  Start up Radio

# %%
radio = si446x_device_start_radio()

# %%
si446x_device_show_config(radio.dump_radio())
# Out:
# int_ctl_group_s: 4
# 0400 0004
#  enable:  CHIP_INT_STATUS_EN chip_pend:  CHIP_READY
#
# global_group_s: 10
# 4000 1820 0000 0160 0000
# Container:
#     xo_tune = 64
#     clk_cfg = Container:
#         divided_clk_en = 'DISABLE'
#         divided_clk_sel = 'DIV_1'
#         clk_32k_sel = 'OFF'
#     low_batt_thresh = 24
#     global_config = Container:
#         sequencer_mode = 'FAST'
#         fifo_mode = 'SPLIT_FIFO'
#         protocol = 'GENERIC'
#         power_mode = 'HIGH_PERF'
#     wut_config = Container:
#         wut_ldc_enable = 'DISABLE'
#         wut_cal_period = '_1_SEC'
#         wut_lbd_en = 'DISABLE'
#         wut_en = 'DISABLE'
#         cal_en = 'DISABLE'
#     wut_m = 1
#     wut_r = Container:
#         RESERVED_WRITE_ONE = 'ONE'
#         wut_sleep = 'SLEEP'
#         wut_r_ = 0
#     wut_ldc = 0
#     wut_cal = 0
#
# synth_group_s: 8
# 2c0e 0b04 0c73 0305
# Container:
#     pfdcp_cpff = 44
#     pfdcp_cpint = 14
#     vco_kv = 11
#     lpfilt3 = 4
#     lpfilt2 = 12
#     lpfilt1 = 115
#     lpfilt0 = 3
#     vco_kvcal = 5
#
# frr_ctl_group_s: 4
# 0102 0900
# 0  0  CURRENT_STATE  DISABLED
#
# modem_group_s: 82
# 0280 070f 4240 01c9 c380 0006 d300 0067 604d 3621 1108 0301 0100 0803 c000 1020 0000 004b 06d3 a006 d302 c000 0023 8369 0040 a000 00e0 0000 1110 100b 1c40 0000 2b0c a403 5602 00a3 0280 ff0c 0100 4003 0008
# Container:
#     mod_type = Container:
#         tx_direct_mode_type = 'SYNC'
#         tx_driect_mode_gpio = 'GPIO_1'
#         mod_source = 'PACKET'
#         mod_type = '_2FSK'
#     map_control = Container:
#         enmanch = 'ENABLE'
#         eninv_rxbit = 'NO_INVERT'
#         eninv_txbit = 'NO_INVERT'
#         eninv_fd = 'NO_INVERT_POL'
#     dsm_ctrl = Container:
#         dsmclk_sel = 'PLL'
#         dsm_mode = 'MASH'
#         dsmdt_en = 'DISABLE'
#         rsmdttp = 'ZERO'
#         dsm_rst = 'ENABLE'
#         dsm_lsb = 'FORCED_HIGH'
#         dsm_order = 'THIRD_ORDER'
#     data_rate = Container:
#         m = 1000000
#     tx_nco_mode = Container:
#         txosr = 'GAUSS_10X'
#         ncomod = 30000000
#     freq_dev = Container:
#         freqdev = 1747
#     freq_offset = 0
#     filter_coeff = 'g`M6!\x11\x08\x03\x01'
#     tx_ramp_delay = 1
#     mdm_ctrl = 0
#     if_control = Container:
#         zeroif = 'NORMAL'
#         fixif = 'FIXED'
#     if_freq = Container:
#         hertz = 245760
#     decimation_cfg1 = 16
#     decimation_cfg0 = 32
#     bcr_osr = 75
#     bcr_nco = Container:
#         offset = 447392
#     bcr_gain = 1747
#     bcr_gear = 2
#     bcr_misc1 = 192
#     bcr_misc0 = 0
#     afc_gear = 0
#     afc_wait = 35
#     afc_gain = 33641
#     afc_limiter = 64
#     afc_misc = 160
#     afc_zipoff = 0
#     adc_ctrl = 0
#     agc_control = 224
#     agc_window_size = 17
#     agc_rffpd_decay = 16
#     agc_ifpd_decay = 16
#     fsk4_gain1 = 11
#     fsk4_gain0 = 28
#     fsk4_th = 16384
#     fsk4_map = 0
#     ook_pdtc = 43
#     ook_blopk = 12
#     ook_cnt1 = 164
#     ook_misc = 3
#     raw_search = 86
#     raw_control = 2
#     raw_eye = 163
#     ant_div_mode = 2
#     ant_div_control = 128
#     rssi_thresh = 255
#     rssi_jump_thesh = 12
#     rssi_control = Container:
#         check_thresh_at_latch = 'DISABLE'
#         average = 'AVERAGE4'
#         latch = 'PREAMBLE'
#     rssi_control2 = Container:
#         rssijmp_dwn = 'DISABLE'
#         rssijmp_up = 'DISABLE'
#         enrssijmp = 'DISABLE'
#         jmpdlylen = '_2_Tb'
#         enjmprx = 'NO_RESET'
#     rssi_comp = 64
#     clkgen_band = 8
#
# rx_hop_group_s: 66
# 0401 0001 0203 0405 0607 0809 0a0b 0c0d 0e0f 1011 1213 1415 1617 1819 1a1b 1c1d 1e1f 2021 2223 2425 2627 2829 2a2b 2c2d 2e2f 3031 3233 3435 3637 3839 3a3b 3c3d 3e3f
# Container:
#     control = 4
#     table_size = 1
#     table_entries = '\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\x0c\r\x0e\x0f\x10\x11\x12\x13\x14\x15\x16\x17\x18\x19\x1a\x1b\x1c\x1d\x1e\x1f !"#$%&\'()*+,-./0123456789:;<=>?'
#
# freq_control_group_s: 8
# 3c08 0000 0000 20ff
# Container:
#     inte = 60
#     frac = Container:
#         i = 524288
#     channel_step_size = 0
#     w_size = 32
#     vcocnt_rx_adj = 255
#
# match_group_s: 12
# 0000 0000 0000 0000 0000 0000
# Container:
#     match_field_s = [
#         Container:
#             value = 0
#             mask = 0
#             ctrl = 0
#         Container:
#             value = 0
#             mask = 0
#             ctrl = 0
#         Container:
#             value = 0
#             mask = 0
#             ctrl = 0
#         Container:
#             value = 0
#             mask = 0
#             ctrl = 0
#     ]
#
# sync_group_s: 5
# 012d d42d d4
# Container:
#     config = Container:
#         skip_tx = 'SYNC_XMIT'
#         rx_errors = 0
#         4fsk = 'DISABLE'
#         manch = 'DISABLE'
#         length = 'LEN_2_BYTES'
#     sync_bits = 768880084
#
# preamble_group_s: 14
# 0814 000f 2100 0000 0000 0000 0000
# Container:
#     tx_length = 8
#     config_std_1 = Container:
#         skip_sync_to = 'DISABLE'
#         wut_r_ = 20
#     config_nstd = Container:
#         rx_errors = 0
#         pattern_length = 0
#     config_std_2 = Container:
#         rx_preamble_timeout_extend = 0
#         rx_preamble_timeout = 15
#     config = Container:
#         pream_frist_1_or_0 = 'First_1'
#         length_config = 'NIBBLE'
#         man_const = 'NO_CON'
#         man_en = 'NO_MAN'
#         standard_pream = 'PRE_1010'
#     pattern = 0
#     postamble_config = Container:
#         postamble_enable = 'DISABLE'
#         pkt_valid_on_postamble = 'TRUE'
#         postamble_size = '_8_BITS'
#     postamble_pattern = 0
#
# pkt_group_s: 53
# 0001 08ff ff00 0000 0000 0030 3000 0000 0000 0000 0000 0000 0000 0000 0000 0000 0000 0000 0000 0000 0000 0000 0000 0000 0000 0000 00
# Container:
#     crc_config = Container:
#         crc_seed = 'CRC_SEED_0'
#         crc_polynomial = 'NO_CRC'
#     wht_poly = 264
#     wht_seed = 65535
#     wht_bit_num = Container:
#         sw_wht_ctrl = 'DISABLE'
#         sw_crc_ctrl = 'DISABLE'
#         wht_bit_num_ = 'ENUM_0'
#     config1 = Container:
#         ph_field_split = 'FIELD_SHARED'
#         ph_rx_disable = 'RX_ENABLED'
#         4fsk_en = 'DISABLE'
#         manch_pol = 'PATTERN_10'
#         crc_invert = 'NO_INVERT'
#         crc_endian = 'LSBYTE_FIRST'
#         bit_order = 'LSBIT_FIRST'
#     len = Container:
#         endian = 'LITTLE'
#         size = 'ONE_BYTE'
#         in_fifo = 'CUT_OUT'
#         dst_field = 'FIXED_LENGTH'
#     len_field_source = Container:
#         src_field = 'FIELD_1'
#     len_adjust = 0
#     tx_threshold = 48
#     rx_threshold = 48
#     tx1 = Container:
#         length = 0
#         config = Container:
#             4fsk = 'DISABLE'
#             pn_start = 'CONTINUE'
#             whiten = 'DISABLE'
#             manch = 'DISABLE'
#         crc_config = Container:
#             crc_start = 'DISABLE'
#             send_crc = 'DISABLE'
#             check_crc = 'DISABLE'
#             crc_enable = 'DISABLE'
#     tx2 = Container:
#         length = 0
#         config = Container:
#             4fsk = 'DISABLE'
#             pn_start = 'CONTINUE'
#             whiten = 'DISABLE'
#             manch = 'DISABLE'
#         crc_config = Container:
#             crc_start = 'DISABLE'
#             send_crc = 'DISABLE'
#             check_crc = 'DISABLE'
#             crc_enable = 'DISABLE'
#     tx3 = Container:
#         length = 0
#         config = Container:
#             4fsk = 'DISABLE'
#             pn_start = 'CONTINUE'
#             whiten = 'DISABLE'
#             manch = 'DISABLE'
#         crc_config = Container:
#             crc_start = 'DISABLE'
#             send_crc = 'DISABLE'
#             check_crc = 'DISABLE'
#             crc_enable = 'DISABLE'
#     tx4 = Container:
#         length = 0
#         config = Container:
#             4fsk = 'DISABLE'
#             pn_start = 'CONTINUE'
#             whiten = 'DISABLE'
#             manch = 'DISABLE'
#         crc_config = Container:
#             crc_start = 'DISABLE'
#             send_crc = 'DISABLE'
#             check_crc = 'DISABLE'
#             crc_enable = 'DISABLE'
#     tx5 = Container:
#         length = 0
#         config = Container:
#             4fsk = 'DISABLE'
#             pn_start = 'CONTINUE'
#             whiten = 'DISABLE'
#             manch = 'DISABLE'
#         crc_config = Container:
#             crc_start = 'DISABLE'
#             send_crc = 'DISABLE'
#             check_crc = 'DISABLE'
#             crc_enable = 'DISABLE'
#     rx1 = Container:
#         length = 0
#         config = Container:
#             4fsk = 'DISABLE'
#             pn_start = 'CONTINUE'
#             whiten = 'DISABLE'
#             manch = 'DISABLE'
#         crc_config = Container:
#             crc_start = 'DISABLE'
#             send_crc = 'DISABLE'
#             check_crc = 'DISABLE'
#             crc_enable = 'DISABLE'
#     rx2 = Container:
#         length = 0
#         config = Container:
#             4fsk = 'DISABLE'
#             pn_start = 'CONTINUE'
#             whiten = 'DISABLE'
#             manch = 'DISABLE'
#         crc_config = Container:
#             crc_start = 'DISABLE'
#             send_crc = 'DISABLE'
#             check_crc = 'DISABLE'
#             crc_enable = 'DISABLE'
#     rx3 = Container:
#         length = 0
#         config = Container:
#             4fsk = 'DISABLE'
#             pn_start = 'CONTINUE'
#             whiten = 'DISABLE'
#             manch = 'DISABLE'
#         crc_config = Container:
#             crc_start = 'DISABLE'
#             send_crc = 'DISABLE'
#             check_crc = 'DISABLE'
#             crc_enable = 'DISABLE'
#     rx4 = Container:
#         length = 0
#         config = Container:
#             4fsk = 'DISABLE'
#             pn_start = 'CONTINUE'
#             whiten = 'DISABLE'
#             manch = 'DISABLE'
#         crc_config = Container:
#             crc_start = 'DISABLE'
#             send_crc = 'DISABLE'
#             check_crc = 'DISABLE'
#             crc_enable = 'DISABLE'
#     rx5 = Container:
#         length = 0
#         config = Container:
#             4fsk = 'DISABLE'
#             pn_start = 'CONTINUE'
#             whiten = 'DISABLE'
#             manch = 'DISABLE'
#         crc_config = Container:
#             crc_start = 'DISABLE'
#             send_crc = 'DISABLE'
#             check_crc = 'DISABLE'
#             crc_enable = 'DISABLE'
#
# modem_chflt_group_s: 36
# ffba 0f51 cfa9 c9fc 1b1e 0f01 fcfd 15ff 000f ffc4 307f f5b5 b8de 0517 160c 0300 15ff 0000
# Container:
#     chflt_rx1_chflt_coe = '\xff\xba\x0fQ\xcf\xa9\xc9\xfc\x1b\x1e\x0f\x01\xfc\xfd\x15\xff\x00\x0f'
#     chflt_rx2_chflt_coe = '\xff\xc40\x7f\xf5\xb5\xb8\xde\x05\x17\x16\x0c\x03\x00\x15\xff\x00\x00'
#
# pa_group_s: 6
# 087f 005d 8023
# power level: 127
#
# === total: 308

# %% [markdown]
# ## Check for Command Error

# %%
status = radio.get_chip_status()
if (status.chip_pend.CMD_ERROR):
    print(status)

# %% [markdown]
# ##  Configure Radio

# %%
config = si446x_device_config_radio(radio)

si446x_device_show_config(radio.dump_radio())
total = 0
print('\n=== const config strings:')
for s in config:
    print((hexlify(s)))
    total += len(s) - 4
print('\n total: {}'.format(total))
# Out:
# int_ctl_group_s: 4
# 033b 2b00
#  enable:  MODEM_INT_STATUS_EN PH_INT_STATUS_EN ph_pend:  PACKET_SENT PACKET_RX CRC_ERROR TX_FIFO_ALMOST_EMPTY RX_FIFO_ALMOST_FULL modem_pend:  INVALID_SYNC RSSI PREAMBLE_DETECT SYNC_DETECT
#
# global_group_s: 10
# 5200 1860 0000 0160 0000
# Container:
#     xo_tune = 82
#     clk_cfg = Container:
#         divided_clk_en = 'DISABLE'
#         divided_clk_sel = 'DIV_1'
#         clk_32k_sel = 'OFF'
#     low_batt_thresh = 24
#     global_config = Container:
#         sequencer_mode = 'FAST'
#         fifo_mode = 'SPLIT_FIFO'
#         protocol = 'GENERIC'
#         power_mode = 'HIGH_PERF'
#     wut_config = Container:
#         wut_ldc_enable = 'DISABLE'
#         wut_cal_period = '_1_SEC'
#         wut_lbd_en = 'DISABLE'
#         wut_en = 'DISABLE'
#         cal_en = 'DISABLE'
#     wut_m = 1
#     wut_r = Container:
#         RESERVED_WRITE_ONE = 'ONE'
#         wut_sleep = 'SLEEP'
#         wut_r_ = 0
#     wut_ldc = 0
#     wut_cal = 0
#
# synth_group_s: 8
# 2c0e 0b04 0c73 0305
# Container:
#     pfdcp_cpff = 44
#     pfdcp_cpint = 14
#     vco_kv = 11
#     lpfilt3 = 4
#     lpfilt2 = 12
#     lpfilt1 = 115
#     lpfilt0 = 3
#     vco_kvcal = 5
#
# frr_ctl_group_s: 4
# 0904 060a
# CURRENT_STATE  INT_PH_PEND  INT_MODEM_PEND  LATCHED_RSSI
#
# modem_group_s: 82
# 0300 0706 1a80 05c9 c380 0005 7600 0067 604d 3621 1108 0301 0180 0803 8000 2020 0000 0177 015d 8600 af02 c200 0436 801d 1004 8000 00e2 0000 1152 5200 1aff ff00 2a0c a402 d683 00ad 0180 200c 2500 4003 000a
# Container:
#     mod_type = Container:
#         tx_direct_mode_type = 'SYNC'
#         tx_driect_mode_gpio = 'GPIO_1'
#         mod_source = 'PACKET'
#         mod_type = '_2GFSK'
#     map_control = Container:
#         enmanch = 'DISABLE'
#         eninv_rxbit = 'NO_INVERT'
#         eninv_txbit = 'NO_INVERT'
#         eninv_fd = 'NO_INVERT_POL'
#     dsm_ctrl = Container:
#         dsmclk_sel = 'PLL'
#         dsm_mode = 'MASH'
#         dsmdt_en = 'DISABLE'
#         rsmdttp = 'ZERO'
#         dsm_rst = 'ENABLE'
#         dsm_lsb = 'FORCED_HIGH'
#         dsm_order = 'THIRD_ORDER'
#     data_rate = Container:
#         m = 400000
#     tx_nco_mode = Container:
#         txosr = 'GAUSS_40X'
#         ncomod = 30000000
#     freq_dev = Container:
#         freqdev = 1398
#     freq_offset = 0
#     filter_coeff = 'g`M6!\x11\x08\x03\x01'
#     tx_ramp_delay = 1
#     mdm_ctrl = 128
#     if_control = Container:
#         zeroif = 'NORMAL'
#         fixif = 'FIXED'
#     if_freq = Container:
#         hertz = 229376
#     decimation_cfg1 = 32
#     decimation_cfg0 = 32
#     bcr_osr = 375
#     bcr_nco = Container:
#         offset = 89478
#     bcr_gain = 175
#     bcr_gear = 2
#     bcr_misc1 = 194
#     bcr_misc0 = 0
#     afc_gear = 4
#     afc_wait = 54
#     afc_gain = 32797
#     afc_limiter = 4100
#     afc_misc = 128
#     afc_zipoff = 0
#     adc_ctrl = 0
#     agc_control = 226
#     agc_window_size = 17
#     agc_rffpd_decay = 82
#     agc_ifpd_decay = 82
#     fsk4_gain1 = 0
#     fsk4_gain0 = 26
#     fsk4_th = 65535
#     fsk4_map = 0
#     ook_pdtc = 42
#     ook_blopk = 12
#     ook_cnt1 = 164
#     ook_misc = 2
#     raw_search = 214
#     raw_control = 131
#     raw_eye = 173
#     ant_div_mode = 1
#     ant_div_control = 128
#     rssi_thresh = 32
#     rssi_jump_thesh = 12
#     rssi_control = Container:
#         check_thresh_at_latch = 'ENABLE'
#         average = 'AVERAGE4'
#         latch = 'RX_STATE3'
#     rssi_control2 = Container:
#         rssijmp_dwn = 'DISABLE'
#         rssijmp_up = 'DISABLE'
#         enrssijmp = 'DISABLE'
#         jmpdlylen = '_2_Tb'
#         enjmprx = 'NO_RESET'
#     rssi_comp = 64
#     clkgen_band = 10
#
# rx_hop_group_s: 66
# 0401 0001 0203 0405 0607 0809 0a0b 0c0d 0e0f 1011 1213 1415 1617 1819 1a1b 1c1d 1e1f 2021 2223 2425 2627 2829 2a2b 2c2d 2e2f 3031 3233 3435 3637 3839 3a3b 3c3d 3e3f
# Container:
#     control = 4
#     table_size = 1
#     table_entries = '\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\x0c\r\x0e\x0f\x10\x11\x12\x13\x14\x15\x16\x17\x18\x19\x1a\x1b\x1c\x1d\x1e\x1f !"#$%&\'()*+,-./0123456789:;<=>?'
#
# freq_control_group_s: 8
# 380e eeee 4444 20fe
# Container:
#     inte = 56
#     frac = Container:
#         i = 978670
#     channel_step_size = 17476
#     w_size = 32
#     vcocnt_rx_adj = 254
#
# match_group_s: 12
# 0000 0000 0000 0000 0000 0000
# Container:
#     match_field_s = [
#         Container:
#             value = 0
#             mask = 0
#             ctrl = 0
#         Container:
#             value = 0
#             mask = 0
#             ctrl = 0
#         Container:
#             value = 0
#             mask = 0
#             ctrl = 0
#         Container:
#             value = 0
#             mask = 0
#             ctrl = 0
#     ]
#
# sync_group_s: 5
# 01b4 2b2d d4
# Container:
#     config = Container:
#         skip_tx = 'SYNC_XMIT'
#         rx_errors = 0
#         4fsk = 'DISABLE'
#         manch = 'DISABLE'
#         length = 'LEN_2_BYTES'
#     sync_bits = 3022728660L
#
# preamble_group_s: 14
# 0814 000f 3100 0000 0000 0000 0000
# Container:
#     tx_length = 8
#     config_std_1 = Container:
#         skip_sync_to = 'DISABLE'
#         wut_r_ = 20
#     config_nstd = Container:
#         rx_errors = 0
#         pattern_length = 0
#     config_std_2 = Container:
#         rx_preamble_timeout_extend = 0
#         rx_preamble_timeout = 15
#     config = Container:
#         pream_frist_1_or_0 = 'First_1'
#         length_config = 'BYTE'
#         man_const = 'NO_CON'
#         man_en = 'NO_MAN'
#         standard_pream = 'PRE_1010'
#     pattern = 0
#     postamble_config = Container:
#         postamble_enable = 'DISABLE'
#         pkt_valid_on_postamble = 'TRUE'
#         postamble_size = '_8_BITS'
#     postamble_pattern = 0
#
# pkt_group_s: 53
# 8501 08ff ff00 8200 2a01 0010 1000 0104 a200 0000 0000 0000 0000 0000 0000 0000 0000 0104 8200 ff00 0a00 0000 0000 0000 0000 0000 00
# Container:
#     crc_config = Container:
#         crc_seed = 'CRC_SEED_1'
#         crc_polynomial = 'CCITT_16'
#     wht_poly = 264
#     wht_seed = 65535
#     wht_bit_num = Container:
#         sw_wht_ctrl = 'DISABLE'
#         sw_crc_ctrl = 'DISABLE'
#         wht_bit_num_ = 'ENUM_0'
#     config1 = Container:
#         ph_field_split = 'FIELD_SPLIT'
#         ph_rx_disable = 'RX_ENABLED'
#         4fsk_en = 'DISABLE'
#         manch_pol = 'PATTERN_10'
#         crc_invert = 'NO_INVERT'
#         crc_endian = 'MSBYTE_FIRST'
#         bit_order = 'LSBIT_FIRST'
#     len = Container:
#         endian = 'BIG'
#         size = 'ONE_BYTE'
#         in_fifo = 'LEAVE_IN'
#         dst_field = 'FIELD_2'
#     len_field_source = Container:
#         src_field = 'FIELD_1_'
#     len_adjust = 0
#     tx_threshold = 16
#     rx_threshold = 16
#     tx1 = Container:
#         length = 1
#         config = Container:
#             4fsk = 'DISABLE'
#             pn_start = 'LOAD'
#             whiten = 'DISABLE'
#             manch = 'DISABLE'
#         crc_config = Container:
#             crc_start = 'ENABLE'
#             send_crc = 'ENABLE'
#             check_crc = 'DISABLE'
#             crc_enable = 'ENABLE'
#     tx2 = Container:
#         length = 0
#         config = Container:
#             4fsk = 'DISABLE'
#             pn_start = 'CONTINUE'
#             whiten = 'DISABLE'
#             manch = 'DISABLE'
#         crc_config = Container:
#             crc_start = 'DISABLE'
#             send_crc = 'DISABLE'
#             check_crc = 'DISABLE'
#             crc_enable = 'DISABLE'
#     tx3 = Container:
#         length = 0
#         config = Container:
#             4fsk = 'DISABLE'
#             pn_start = 'CONTINUE'
#             whiten = 'DISABLE'
#             manch = 'DISABLE'
#         crc_config = Container:
#             crc_start = 'DISABLE'
#             send_crc = 'DISABLE'
#             check_crc = 'DISABLE'
#             crc_enable = 'DISABLE'
#     tx4 = Container:
#         length = 0
#         config = Container:
#             4fsk = 'DISABLE'
#             pn_start = 'CONTINUE'
#             whiten = 'DISABLE'
#             manch = 'DISABLE'
#         crc_config = Container:
#             crc_start = 'DISABLE'
#             send_crc = 'DISABLE'
#             check_crc = 'DISABLE'
#             crc_enable = 'DISABLE'
#     tx5 = Container:
#         length = 0
#         config = Container:
#             4fsk = 'DISABLE'
#             pn_start = 'CONTINUE'
#             whiten = 'DISABLE'
#             manch = 'DISABLE'
#         crc_config = Container:
#             crc_start = 'DISABLE'
#             send_crc = 'DISABLE'
#             check_crc = 'DISABLE'
#             crc_enable = 'DISABLE'
#     rx1 = Container:
#         length = 1
#         config = Container:
#             4fsk = 'DISABLE'
#             pn_start = 'LOAD'
#             whiten = 'DISABLE'
#             manch = 'DISABLE'
#         crc_config = Container:
#             crc_start = 'ENABLE'
#             send_crc = 'DISABLE'
#             check_crc = 'DISABLE'
#             crc_enable = 'ENABLE'
#     rx2 = Container:
#         length = 255
#         config = Container:
#             4fsk = 'DISABLE'
#             pn_start = 'CONTINUE'
#             whiten = 'DISABLE'
#             manch = 'DISABLE'
#         crc_config = Container:
#             crc_start = 'DISABLE'
#             send_crc = 'DISABLE'
#             check_crc = 'ENABLE'
#             crc_enable = 'ENABLE'
#     rx3 = Container:
#         length = 0
#         config = Container:
#             4fsk = 'DISABLE'
#             pn_start = 'CONTINUE'
#             whiten = 'DISABLE'
#             manch = 'DISABLE'
#         crc_config = Container:
#             crc_start = 'DISABLE'
#             send_crc = 'DISABLE'
#             check_crc = 'DISABLE'
#             crc_enable = 'DISABLE'
#     rx4 = Container:
#         length = 0
#         config = Container:
#             4fsk = 'DISABLE'
#             pn_start = 'CONTINUE'
#             whiten = 'DISABLE'
#             manch = 'DISABLE'
#         crc_config = Container:
#             crc_start = 'DISABLE'
#             send_crc = 'DISABLE'
#             check_crc = 'DISABLE'
#             crc_enable = 'DISABLE'
#     rx5 = Container:
#         length = 0
#         config = Container:
#             4fsk = 'DISABLE'
#             pn_start = 'CONTINUE'
#             whiten = 'DISABLE'
#             manch = 'DISABLE'
#         crc_config = Container:
#             crc_start = 'DISABLE'
#             send_crc = 'DISABLE'
#             check_crc = 'DISABLE'
#             crc_enable = 'DISABLE'
#
# modem_chflt_group_s: 36
# a281 26af 3fee c8c7 dbf2 0208 0703 15fc 0f00 a281 26af 3fee c8c7 dbf2 0208 0703 15fc 0f00
# Container:
#     chflt_rx1_chflt_coe = '\xa2\x81&\xaf?\xee\xc8\xc7\xdb\xf2\x02\x08\x07\x03\x15\xfc\x0f\x00'
#     chflt_rx2_chflt_coe = '\xa2\x81&\xaf?\xee\xc8\xc7\xdb\xf2\x02\x08\x07\x03\x15\xfc\x0f\x00'
#
# pa_group_s: 6
# 087f 003d 8023
# power level: 127
#
# === total: 308
#
# === const config strings:
# 1300000000000000
# 110002005200
# 1100010360
# 110102000120
# 111001000a
# 1110010431
# 1111030001b42b
# 1112010602
# 1112010f04
# 11200c00030007061a8005c9c3800005
# 1120010c76
# 112008180180080380002020
# 112009220177015d8600af02c2
# 1120072c0436801d100480
# 11200135e2
# 11200938115252001affff002a
# 11200842a402d68300ad0180
# 1120014e40
# 112001510a
# 11210c00a28126af3feec8c7dbf20208
# 11210c0c070315fc0f00a28126af3fee
# 11210c18c8c7dbf20208070315fc0f00
# 11220400087f003d
# 112307002c0e0b040c7303
# 11400800380eeeee444420fe
# 131c082120000000
# 1100010360
# 11010400033b2b00
# 111009000814000f31
# 11120700850108ffff0082
# 111205082a01003030
# 1112060d000104a20000
# 11120a210001048200ff000a0000
# 1120034a200c25
#
#  total: 173

# %% [markdown]
# ## Transfer Software Image using TagNet

# %% [markdown]
# ### Image Info description
# Image Description Information stored in the Image File

# %%
#filename    = '/tmp/test.bin'
filename    = 'main.bin'

# %% [raw]
# C structures from TAG code define image info metadata
#
# typedef struct {                        /* little endian order  */
#   uint16_t build;                       /* that's native for us */
#   uint8_t  minor;
#   uint8_t  major;
# } image_ver_t;
#
# typedef struct {
#   uint8_t  hw_rev;
#   uint8_t  hw_model;
# } hw_ver_t;
#
# typedef struct {
#   uint32_t    sig;                      /* must be IMAGE_INFO_SIG to be valid */
#   uint32_t    image_start;              /* where this binary loads            */
#   uint32_t    image_length;             /* byte length of entire image        */
#   uint32_t    vector_chk;               /* simple checksum over vector table  */
#   uint32_t    image_chk;                /* simple checksum over entire image  */
#   image_ver_t ver_id;
#   hw_ver_t    hw_ver;
# } image_info_t;

# %%
#  IMAGE_INFO provides information about a Tag software image. This data is
#  embedded in the image itself. The IMAGE_META_OFFSET is the offset into
#  the image where image_info lives in the image.  It directly follows the
#  exception vectors which are 0x140 bytes long.
# 
#  This struct will have to change, If MSP432 vector table length changes.
# 
IMAGE_INFO_SIG = 0x33275401
IMAGE_META_OFFSET = 0x140
IMAGE_INFO_DEFAULT = [IMAGE_INFO_SIG, 0x20000, (0x140*2)+0x1c, 0, 0, 257, 2, 3, ' '  * 40, ' '  * 40, ' '  * 30, 0xde, 2]
#
# Struct created for accessing image info (little indian)
# sig, image_start, imagelength, vector_chk, image_chk, im_build, im_minor, im_major, main_tree, aux_tree, build_time, im_rev, im_model = image_info
#
IM_FIELDS = '<LLLLLHBB44s44s30sBB'
image_info_struct = pystruct.Struct(IM_FIELDS)
IMAGE_MIN_SIZE  =  (IMAGE_META_OFFSET + image_info_struct.size)

# %%
# write out simple default binary input file for testing purposes
#
if not os.path.isfile(filename):
    with open(filename,'wb') as outfile:
        buf = bytearray(IMAGE_META_OFFSET)
        for x in range(1,IMAGE_META_OFFSET): buf[x] = x & 0x7f
        outfile.write(buf)
        outfile.write(bytearray(image_info_struct.pack(*IMAGE_INFO_DEFAULT)))
        for i in range(64):
            for x in range(256): buf[x] = x & 0x7f
            outfile.write(buf)

# %%
try:
    infile = open(filename, 'rb')
    infile.seek(0, 2) # seek to the end
    file_size = infile.tell()
    if file_size < IMAGE_MIN_SIZE: raise RadioLoadException("input file too short")
    infile.seek(0, 0)    # seek to the beginnnig
    # get image info from input file and sanity check
    infile.seek(IMAGE_META_OFFSET) # seek to location of image info
    image_info = image_info_struct.unpack(infile.read(image_info_struct.size))
    print("file information")
    sig, image_start, imagelength, vector_chk, image_chk, im_build, im_minor, im_major,\
        main_tree, aux_tree, build_time, im_rev, im_model = image_info
    pstr = "  signature: 0x{:x}, start: 0x{:x}, length: 0x{:x}, vect_chk: 0x{:x}, image_chk: 0x{:x}"
    print(pstr.format(sig, image_start, imagelength, vector_chk, image_chk))
    pstr = "  version: ({}.{}.{}(0x{:x})), rev: {}, model: {}"
    print(pstr.format(im_major, im_minor, im_build, im_build, im_rev, im_model))
    if sig != IMAGE_INFO_SIG: raise RadioLoadException("image metadata is invalid")
    infile.seek(0)    # seek to the beginning
    
finally:
    infile.close()
# Out:
# file information
#   signature: 0x33275401, start: 0x0, length: 0x1a5c4, vect_chk: 0x0, image_chk: 0x0
#   version: (0.1.126(0x7e)), rev: 1, model: 0

# %% [markdown]
# ### utility routines for handling image load

# %%
# debug flags
PRINT_MAX = 80

# %%
# default paramters
MAX_WAIT            = 10
MAX_RECV            = 255
MAX_PAYLOAD         = 254
MAX_RETRIES         = 10
RADIO_POWER         = 100
SHORT_DELAY         = 0

# %%
# build Image PUT Request
def im_send_request(fd, write_max, vers, eof=False):
    # base image name
    req_name = TagName ('/tag/sd') \
                + TagTlv(tlv_types.NODE_ID, -1) \
                + TagTlv(0) \
                + TagTlv('img') \
                + TagTlv(tlv_types.VERSION, vers)
    # optionally add offset to name
    if (fd.tell() > 0):
        req_name = req_name + TagTlv(tlv_types.OFFSET, fd.tell())
    # build the PUT mesage object
    req_obj = TagPut(req_name)
    # optionally add payload
    if eof:
        # send end of file indication
        pload = TagTlvList([TagTlv(tlv_types.EOF)])
    elif (fd.tell() < write_max):
        # determine payload size to send and read it
        chunk_size = MAX_PAYLOAD - req_obj.pkt_len()
        if ((file_size - fd.tell()) < chunk_size):
            chunk_size = file_size - fd.tell()
        pload = bytearray(fd.read(chunk_size))
    # else
        # just send without payload
    
    # print out details of request
#    print(req_obj.header)
#    print(req_obj.name)
    if (pload is not None):
        req_obj.payload = pload
    req_msg = req_obj.build()
#    print("   ", hexlify(req_msg[:PRINT_MAX]),"...", hexlify(req_msg[-PRINT_MAX:]))
    
#    print("REQUEST MSG,  msg len: {},  payload len: {}".format(len(req_msg), len(pload)))
    # send request msg
    si446x_device_send_msg(radio, req_msg, RADIO_POWER);
    del req_name
    return req_obj, req_msg, len(pload)

# %%
req_name = TagName ('/tag/sd') \
                + TagTlv(tlv_types.NODE_ID, -1) \
                + TagTlv(0) \
                + TagTlv('img') \
                + TagTlv(tlv_types.VERSION, (0,0,0))
req_obj = TagPut(req_name)
req_obj.payload = TagTlvList([TagTlv(tlv_types.EOF)])
req_msg = req_obj.build()
#print(hexlify(req_msg))

# %%
def im_get_response(fd):
    rsp_buf, rssi, status = si446x_device_receive_msg(radio, MAX_RECV, MAX_WAIT)
    if (not rsp_buf):
        return None, None, -1, 0
    rsp_obj = TagMessage(rsp_buf)
    # get offset
    offset = 0
    if (rsp_obj.payload) and (rsp_obj.payload[0].tlv_type() == tlv_types.OFFSET):
        offset = rsp_obj.payload[0].value()
    # print out details of response
#    print()
#    print("RESPONSE MSG, error: {}".format(rsp_obj.header.options.param.error_code))
#    print(rsp_obj.header)
#    print(rsp_obj.name)
#    if (rsp_obj.payload):
#        print(rsp_obj.payload)
#        print("   offset: {}, msg len: {},  payload len: {}, rssi: {}".format(offset, len(rsp_buf), 0, rssi))
#        print("   ", hexlify(rsp_buf[:PRINT_MAX]),"...", hexlify(rsp_buf[-PRINT_MAX:]))
    return rsp_obj, rsp_buf, offset, rssi;

# %%
from __future__ import print_function
from datetime import datetime

# %% [markdown]
# ### main funtion for transfer of image to tag

# %%
radio.trace._enable()
# set rssi control (enable latch, average4, latch on sync)
prp         = bytearray('0x22')
radio.set_property('MODEM', 0x4c, prp) 
# tx/rx threshold
#prp = bytearray('\x20\x20')
#radio.set_property('PKT', 0x0b, prp)
start = datetime.now()
print(start)
class RadioLoadException(Exception):
    pass
try:
    # open input file and determine its length
    infile = open(filename, 'rb')
    infile.seek(0, 2) # seek to the end
    file_size = infile.tell()
    if file_size < IMAGE_MIN_SIZE: raise RadioLoadException("input file too short")
    infile.seek(0, 0)    # seek to the beginnnig
    # get image info from input file and sanity check
    infile.seek(IMAGE_META_OFFSET) # seek to location of image info
    image_info = image_info_struct.unpack(infile.read(image_info_struct.size))
    print("file information")
    sig, image_start, imagelength, vector_chk, image_chk, im_build, im_minor, im_major,\
        main_tree, aux_tree, build_time, im_rev, im_model = image_info
    pstr = "  signature: 0x{:x}, start: 0x{:x}, length: 0x{:x}, vect_chk: 0x{:x}, image_chk: 0x{:x}"
    print(pstr.format(sig, image_start, imagelength, vector_chk, image_chk))
    pstr = "  version: ({}.{}.{}(0x{:x})), rev: {}, model: {}"
    print(pstr.format(im_major, im_minor, im_build, im_build, im_rev, im_model))
    if sig != IMAGE_INFO_SIG: raise RadioLoadException("image metadata is invalid")
    infile.seek(0)    # seek to the beginnnig
    # loop to transfer image data to tag
    retries         = 0
    total_retries   = 0
    packets_sent    = 0
    rssi            = 0
    while (file_size - infile.tell() > 0):
        if ((packets_sent % 10) == 0):
            print("\r{0:.2f}%".format((float(infile.tell())/float(file_size))*100), end='')
#        print(">>>> file size: {}, offset: {}, retries: {}, rssi: {}\r".format(file_size, infile.tell(), retries, rssi, end=''))
        __, __, plen = im_send_request(infile, file_size, (im_build, im_minor, im_major))
        packets_sent += 1
#        print("----")
        rsp_obj, rsp_msg, offset, rssi = im_get_response(infile)
        # check that offset is expected
        if offset != infile.tell():
            if (rsp_obj is None): p = "TIMEOUT"
            else:                 p = "BAD OFFSET"
            print("\n{}  {}! offset: response {}, expected {}".format(datetime.now(), p, offset, infile.tell()))
            if (offset >= 0):
                infile.seek(offset, 0)
            else:
                infile.seek(-plen, 1)
                offset -= plen
                
            retries = retries + 1
            total_retries = total_retries + 1
        else:
            retries = 0
        if (retries > MAX_RETRIES):
            raise RadioLoadException("too many retries")
        sleep(SHORT_DELAY)
    # send end of file to complete the image load operation
    im_send_request(infile, file_size, (im_build, im_minor, im_major), True)
    rsp_obj, rsp_msg, offset, rssi = im_get_response(infile)
    print("\ntotals bytes: {}, packets: {} retries: {}".format(offset, packets_sent, total_retries))
except RadioLoadException:
    print('terminating')
finally:
    infile.close()
print('\ndone, elapsed time', datetime.now() - start)
# Out:
# 2017-11-28 12:31:22.804054
# file information
#   signature: 0x33275401, start: 0x0, length: 0x1a5c4, vect_chk: 0x0, image_chk: 0x0
#   version: (0.1.126(0x7e)), rev: 1, model: 0
# 0.00%
# 2017-11-28 12:31:33.147329  TIMEOUT! offset: response -1, expected 219
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-14a73132132d> in <module>()
#      40         packets_sent += 1
#      41 #        print("----")
# ---> 42         rsp_obj, rsp_msg, offset, rssi = im_get_response(infile)
#      43         # check that offset is expected
#      44         if offset != infile.tell():
#
# <ipython-input-17-68f8330bac4e> in im_get_response(fd)
#       1 def im_get_response(fd):
# ----> 2     rsp_buf, rssi, status = si446x_device_receive_msg(radio, MAX_RECV, MAX_WAIT)
#       3     if (not rsp_buf):
#       4         return None, None, -1, 0
#       5     rsp_obj = TagMessage(rsp_buf)
#
# <ipython-input-2-aed817674d87> in si446x_device_receive_msg(radio, max_recv, wait)
#      59             cflags.chip_pend.FIFO_UNDERFLOW_OVERFLOW_ERROR = False
#      60             break
# ---> 61         status = int_status(cflags, show)
#      62     status = int_status()
#      63     pkt_len = radio.get_packet_info()
#
# <ipython-input-2-27847d847a20> in int_status(clr_flags, show)
#       4     clr_flags = clr_flags if (clr_flags) else clr_pend_int_s.parse('\xff' * clr_pend_int_s.sizeof())
#       5     clr_flags.ph_pend.STATE_CHANGE = False
# ----> 6     p_g = radio.get_clear_interrupts(clr_flags)
#       7     p_d = p_s.build(p_g)
#       8     if (show is True):
#
# /mnt/Open/TagNet/si446x/si446x/si446xradio.pyc in get_clear_interrupts(self, clr_flags)
#     423         Refer to structures defined by the Si4463 radio API revB1B.
#     424         """
# --> 425         self.clear_interrupts(clr_flags)
#     426         rsp = self.spi.response(int_status_rsp_s.sizeof(), int_status_rsp_s.name)
#     427         if (rsp):
#
# /mnt/Open/TagNet/si446x/si446x/si446xradio.pyc in clear_interrupts(self, clr_flags)
#     239         request = read_cmd_s.parse('\x00' * read_cmd_s.sizeof())
#     240         request.cmd='GET_INT_STATUS'
# --> 241         cf = clr_pend_int_s.build(clr_flags) if (clr_flags) else ''
#     242         cmd = read_cmd_s.build(request) + cf
#     243         s_name = get_clear_int_cmd_s.name if (cf) else read_cmd_s.name
#
# /usr/local/lib/python2.7/dist-packages/construct/core.pyc in build(self, obj)
#     210         """
#     211         stream = BytesIO()
# --> 212         self.build_stream(obj, stream)
#     213         return stream.getvalue()
#     214
#
# /usr/local/lib/python2.7/dist-packages/construct/core.pyc in build_stream(self, obj, stream)
#     217         Build an object directly into a stream.
#     218         """
# --> 219         self._build(obj, stream, Container())
#     220
#     221     def _build(self, obj, stream, context):
#
# /usr/local/lib/python2.7/dist-packages/construct/core.pyc in _build(self, obj, stream, context)
#     689                 subobj = getattr(obj, sc.name)
#     690                 context[sc.name] = subobj
# --> 691             sc._build(subobj, stream, context)
#     692     def _sizeof(self, context):
#     693         #if self.nested:
#
# /usr/local/lib/python2.7/dist-packages/construct/core.pyc in _build(self, obj, stream, context)
#     271         return self.subcon._parse(stream, context)
#     272     def _build(self, obj, stream, context):
# --> 273         self.subcon._build(obj, stream, context)
#     274     def _sizeof(self, context):
#     275         return self.subcon._sizeof(context)
#
# /usr/local/lib/python2.7/dist-packages/construct/core.pyc in _build(self, obj, stream, context)
#     689                 subobj = getattr(obj, sc.name)
#     690                 context[sc.name] = subobj
# --> 691             sc._build(subobj, stream, context)
#     692     def _sizeof(self, context):
#     693         #if self.nested:
#
# /usr/local/lib/python2.7/dist-packages/construct/core.pyc in _build(self, obj, stream, context)
#    1098         size = self._sizeof(context)
#    1099         stream2 = BytesIO()
# -> 1100         self.subcon._build(obj, stream2, context)
#    1101         data = self.encoder(stream2.getvalue())
#    1102         assert len(data) == size
#
# /usr/local/lib/python2.7/dist-packages/construct/core.pyc in _build(self, obj, stream, context)
#     688             else:
#     689                 subobj = getattr(obj, sc.name)
# --> 690                 context[sc.name] = subobj
#     691             sc._build(subobj, stream, context)
#     692     def _sizeof(self, context):
#
# /usr/local/lib/python2.7/dist-packages/construct/lib/container.pyc in __setitem__(self, key, val)
#      34         except KeyError:
#      35             raise AttributeError(name)
# ---> 36     def __setitem__(self, key, val):
#      37         if key not in self:
#      38             self.__keys_order__.append(key)
#
# KeyboardInterrupt:

# %%
print(hexlify(rsp_buf))
print(offset)
print(rsp_obj.header)
print(rsp_obj.header.options.param.error_code)
print(rsp_obj.name)
print(rsp_obj.payload)

# %% [markdown]
# ## Get Directory

# %%
#"tag"  "sd"    <node_id>   "img"
image_manager_name = TagName ('/tag/sd') \
                + TagTlv(tlv_types.NODE_ID, -1) \
                + TagTlv(0) \
                + TagTlv('img')
dir_info = TagGet(image_manager_name)
#print(dir_info.name)
dir_msg = dir_info.build()
#print(len(dir_msg),hexlify(dir_msg))
si446x_device_send_msg(radio, dir_msg, RADIO_POWER);
rsp_buf, rssi, status = si446x_device_receive_msg(radio, MAX_RECV, MAX_WAIT)
if (rsp_buf):
    print(len(rsp_buf),hexlify(rsp_buf))
    rsp_obj = TagMessage(rsp_buf)
    for x in range(0, 8, 2):
        print("state: {}, {}".format(rsp_obj.payload[x+1].value(), rsp_obj.payload[x]))
else:
    print('timeout')
# Out:
# 65 409180190103746167010273640506ffffffffffff0201000103696d670a04000000000101780a04000000000101780a04000000000101780a0400000000010178
# state: x, (tlv_types.VERSION, [0, 0, 0])
# state: x, (tlv_types.VERSION, [0, 0, 0])
# state: x, (tlv_types.VERSION, [0, 0, 0])
# state: x, (tlv_types.VERSION, [0, 0, 0])

# %% [markdown]
# ## Get Versions

# %%
#"tag"	"sys"	<node_id>	"which"
def get_version(which):
    sys_name = TagName ('/tag/sys') \
                        + TagTlv(tlv_types.NODE_ID, -1) \
                        + TagTlv(which)
    sys_obj = TagGet(sys_name)
#    print(sys_obj.name)
    get_msg = sys_obj.build()
    si446x_device_send_msg(radio, get_msg, RADIO_POWER);
    rsp_buf, rssi, status = si446x_device_receive_msg(radio, MAX_RECV, 5)
    if(rsp_buf):
#        print(hexlify(rsp_buf))
        rsp_obj = TagMessage(rsp_buf)
        print("{} {:^10} state: {}, {}".format(rsp_obj.header.options.param.error_code, \
                                                         which, rsp_obj.payload[1].value(),       \
                                                         rsp_obj.payload[0]))

# %%
get_version('active')
get_version('backup')
get_version('golden')
get_version('nib')
get_version('running')
# Out:
# OK   active   state:  , (tlv_types.VERSION, [8734, 0, 32])
# OK   backup   state:  , (tlv_types.VERSION, [0, 0, 0])
# OK   golden   state: G, (tlv_types.VERSION, [177, 1, 0])
# OK    nib     state: N, (tlv_types.VERSION, [65535, 255, 255])
# OK  running   state: G, (tlv_types.VERSION, [177, 1, 0])

# %% [markdown]
# ## Def Set Active/Backup Version

# %%
#"tag"	"sys"	<node_id>	"which"
def set_version(which, version):
    set_name = TagName ('/tag/sys') \
                        + TagTlv(tlv_types.NODE_ID, -1) \
                        + TagTlv(which) \
                        + TagTlv(tlv_types.VERSION, version)
    set_obj = TagPut(set_name)
#    print(set_obj.name)
    set_msg = set_obj.build()
    si446x_device_send_msg(radio, set_msg, RADIO_POWER);
    rsp_buf, rssi, status = si446x_device_receive_msg(radio, MAX_RECV, 5)
    if(rsp_buf):
#        print(hexlify(rsp_buf))
        rsp_obj = TagMessage(rsp_buf)
#        print(rsp_obj.header)
        if (rsp_obj.payload):
            print("{}: state: {}, {}".format(rsp_obj.header.options.param.error_code, rsp_obj.payload[1].value(), rsp_obj.payload[0]))
        else:
            print("{}".format(rsp_obj.header.options.param.error_code))

# %% [markdown]
# ## Set Active Version

# %%
set_version('active', (118, 1, 0))

# %% [markdown]
# ## Set Backup Version

# %%
set_version('backup', (112, 1, 0))

# %% [markdown]
# ## Reboot Running Version

# %%
set_version('running', (116, 1, 0))

# %% [markdown]
# ## Reboot NIB

# %%
set_version('nib', (115, 1, 0))

# %% [markdown]
# ## Reboot Golden

# %%
set_version('golden', (117, 1, 0))

# %% [markdown]
# ## Delete Version

# %%
#"tag"  "sd"    <node_id>   "img"   <version>
delete_image_name = TagName ('/tag/sd') \
                + TagTlv(tlv_types.NODE_ID, -1) \
                + TagTlv(0) \
                + TagTlv('img') \
                + TagTlv(tlv_types.VERSION, (4, 1, 0))
delete_info = TagDelete(delete_image_name)
#print(delete_info.header)
print(delete_info.name)
delete_msg = delete_info.build()
si446x_device_send_msg(radio, delete_msg, RADIO_POWER);
rsp_buf, rssi, status = si446x_device_receive_msg(radio, MAX_RECV, 5)
if(rsp_buf):
#    print(hexlify(rsp_buf))
    rsp_obj = TagMessage(rsp_buf)
#    print(rsp_obj.header.options.param.error_code)
#    print(rsp_obj.payload)
    if (rsp_obj.payload):
        print("{}: state: {}, {}".format(rsp_obj.header.options.param.error_code, rsp_obj.payload[1].value(), rsp_obj.payload[0]))
    else:
        print("{}".format(rsp_obj.header.options.param.error_code))

# %% [markdown]
# ## Get Chip Status

# %%
print(radio.get_chip_status())

# %% [markdown]
# ## Interactive Group Properties

# %%
from ipywidgets import interact
interact(si446x_device_group_fetch_and_decode, group=radio_config_group_ids.encoding)

# %% [markdown]
# ## Interactive  Command Status Responses

# %%
interact(si446x_device_command_fetch_and_decode, cmd=radio_status_cmd_ids.encoding)

# %%
from datetime import datetime
datetime.now()
